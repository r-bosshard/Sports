# %%
import pandas as pd
import numpy as np
import requests
import random
import math
import matplotlib.pyplot as plt
from scipy import stats
from scipy import stats, special
from sklearn import model_selection, metrics, linear_model, datasets, feature_selection
from lxml import html

# %%
PGA_base_url = "https://statdata.pgatour.com/r/" 

#Check PGA for current tournament

PGA_current= "https://statdata.pgatour.com/r/current/message.json"
r = requests.get(PGA_current)
r_json = r.json()
current_id = r_json['tid']
current_url = "https://statdata.pgatour.com/r/{0}".format(current_id)

#Current tournament's JSON

PGA_current_url = "{0}/leaderboard-v2mini.json".format(current_url)

r = requests.get(PGA_current_url)
r_json = r.json()
current_tournament = r_json["debug"]["tournament_in_schedule_file_name"]
print(current_tournament)
print(PGA_current_url)
# Out:
# A Military Tribute at The Greenbrier
# https://statdata.pgatour.com/r/490/leaderboard-v2mini.json

# %%
team1 = "Rob"
team1_list = {"Tim Wilkinson", "Bill Haas", "Jhonattan Vegas"}

team2 = "John"
team2_list = {"Matthieu Pavon", "Cameron Wilson", "Brandt Snedeker"}

team3 = "Joe"
team3_list = {"Kiradech Aphibarnrat", "Steve Stricker", "Gary Woodland"}


teams = {team1 : team1_list, team2 : team2_list, team3 : team3_list}

# %%
PGA_base_url = "https://statdata.pgatour.com/r/" 

#Check PGA for current tournament

PGA_current= "https://statdata.pgatour.com/r/current/message.json"
r = requests.get(PGA_current)
r_json = r.json()
current_id = r_json['tid']
current_url = "https://statdata.pgatour.com/r/{0}".format(current_id)

#Current tournament's JSON

PGA_current_url = "{0}/leaderboard-v2mini.json".format(current_url)

r = requests.get(PGA_current_url)
r_json = r.json()
current_tournament = r_json["debug"]["tournament_in_schedule_file_name"]

#Create Scoreboard

field = 156
score = r_json["leaderboard"]["players"]

team_list = []

for team in teams.keys():
    players = teams[team]
    for player in players:
        name = player.split()
        for i in range(0, field):
            try:
                if name[0] == score[i]["player_bio"]["first_name"]:
                    if name[1] == score[i]["player_bio"]["last_name"]:
                        row_dict = {"Team": team,
                                "Player": player,
                                'Today': score[i]["today"],
                                'Total' : score[i]["total"],
                                'Thru': score[i]["thru"]}
                        team_list.append(row_dict)

            except:
                print(i)

df = pd.DataFrame(team_list)
df = df.set_index("Team")
df = df[["Player","Today","Total","Thru"]]


#create team score

score_list = []
for team in teams.keys():
    score = 0
    count = -1 
    for i in list(df.index):
        count = count + 1
        if i == team:
            score = score + df.iloc[count][1]
    score_dict = {"Team": team, "Score": score}
    score_list.append(score_dict)        
    
df_score = pd.DataFrame(score_list)
df_score = df_score.set_index("Team")

df["Score"] = df_score

#clean scores

for i in range(0,len(df.index)):
    if i % len(list(teams[team1])) != 0:
        df.iloc[i, df.columns.get_loc('Score')] = ""
        
#drop the worst score

    else:
        df.iloc[i, df.columns.get_loc('Score')] = df.iloc[i][4] - df.iloc[i:i+len(list(teams[team1]))]["Today"].max()


df
# Out:
#                Player  Today  Total  Thru Score
# Team
# Rob         Bill Haas    NaN     -1   NaN   NaN
# John  Brandt Snedeker   -6.0    -13  18.0

# %%
#Current Season Champion List

PGA_base_url = "https://statdata.pgatour.com/r/" 

#Check PGA for current tournament

PGA_current= "https://statdata.pgatour.com/r/current/message.json"
r = requests.get(PGA_current)
r_json = r.json()
current_id = r_json['tid']

tourn_id = ['002',
 '003',
 '004',
 '005',
 '006',
 '007',
 '009',
 '010',
 '011',
 '012',
 '014',
 '016',
 '018',
 '019',
 '020',
 '021',
 '023',
 '025',
 '026',
 '034',
 '041',
 '471',
 '473',
 '475',
 '480',
 '490']

champion_list = []

for i in tourn_id:
    
    try:

        current_url = "https://statdata.pgatour.com/r/{0}".format(i)

        #Current tournament's JSON

        PGA_current_url = "{0}/leaderboard-v2mini.json".format(current_url)

        r = requests.get(PGA_current_url)
        r_json = r.json()
        current_tournament = r_json["debug"]["tournament_in_schedule_file_name"]
        champion = r_json["leaderboard"]["players"][0]["player_bio"]["last_name"]
        date = r_json["leaderboard"]["end_date"]
        second = r_json["leaderboard"]["players"][1]["player_bio"]["last_name"]
        third = r_json["leaderboard"]["players"][2]["player_bio"]["last_name"]
        fourth = r_json["leaderboard"]["players"][3]["player_bio"]["last_name"]
        fifth = r_json["leaderboard"]["players"][4]["player_bio"]["last_name"]
        
        row_dict = {"Tournament" : current_tournament, "Champion" : champion, "Date"  : date, "2nd" : second,
                   "3rd" : third, "4th" : fourth, "5th" : fifth}
        
        champion_list.append(row_dict)
        
    except:
        
        print(PGA_current_url)
        
        
        

df = pd.DataFrame(champion_list)
df = df.set_index("Date")
df = df[["Tournament","Champion", "2nd", "3rd", "4th", "5th"]]
df=df.sort_index()

df
# Out:
#                                                    Tournament     Champion  \
# Date
# 2018-01-07                     Sentry Tournament of Champions      Johnson
# 2018-01-14                                Sony Open in Hawaii      Kizzire
# 2018-01-21                            CareerBuilder Challenge         Rahm
# 2018-01-28                             Farmers Insurance Open          Day
# 2018-02-04                      Waste Management Phoenix Open     Woodland
# 2018-02-11                           AT&T Pebble Beach Pro-Am  Potter, Jr.
# 2018-02-18                                       Genesis Open       Watson
# 2018-02-25                                  The Honda Classic       Thomas
# 2018-03-04       World Golf Championships-Mexico Championship    Mickelson
# 2018-03-11                               Valspar Championship        Casey
# 2018-03-18  Arnold Palmer Invitational presented by Master...      McIlroy
# 2018-04-01                                       Houston Open      Poulter
# 2018-04-08                                 Masters Tournament         Reed
# 2018-04-15                                       RBC Heritage      Kodaira
# 2018-04-22                                  Valero Texas Open       Landry
# 2018-04-29                      Zurich Classic of New Orleans     Horschel
# 2018-05-06                           Wells Fargo Championship          Day
# 2018-05-13                           THE PLAYERS Championship      Simpson
# 2018-05-20                                  AT&T Byron Nelson         Wise
# 2018-05-27                            Fort Worth Invitational         Rose
# 2018-06-03    the Memorial Tournament presented by Nationwide   DeChambeau
# 2018-06-10                             FedEx St. Jude Classic      Johnson
# 2018-06-17                                          U.S. Open       Koepka
# 2018-06-24                             Travelers Championship       Watson
# 2018-07-01                             Quicken Loans National     Molinari
# 2018-07-08               A Military Tribute at The Greenbrier           Na
#
#                    2nd            3rd         4th          5th
# Date
# 2018-01-07        Rahm         Harman   Matsuyama        Perez
# 2018-01-14        Hahn           Hoge     Simpson       Stuard
# 2018-01-21      Landry            Huh      Hadwin       Piller
# 2018-01-28       Noren         Palmer      Holmes      Bradley
# 2018-02-04      Reavie  Schniederjans      Steele       Hadley
# 2018-02-11   Mickelson         Reavie         Day      Johnson
# 2018-02-18          Na          Finau   Stallings      Cantlay
# 2018-02-25        List          Noren   Fleetwood           An
# 2018-03-04      Thomas  Cabrera Bello      Hatton  Aphibarnrat
# 2018-03-11        Reed          Woods      Garcia    Sabbatini
# 2018-03-18  DeChambeau           Rose     Stenson        Woods
# 2018-04-01     Hossler         Spieth      Grillo        Ryder
# 2018-04-08      Fowler         Spieth        Rahm        Smith
# 2018-04-15         Kim     DeChambeau        List      Simpson
# 2018-04-22      O'Hair       Mullinax      Walker      Johnson
# 2018-04-29      Piercy         Dufner       Perez   Schwartzel
# 2018-05-06        Wise         Watney  DeChambeau    Mickelson
# 2018-05-13  Schwartzel         Walker  Schauffele          Day
# 2018-05-20    Leishman          Grace       Spaun     Mitchell
# 2018-05-27      Koepka         Grillo          Na         Tway
# 2018-06-03          An        Stanley     Cantlay      Uihlein
# 2018-06-10      Putnam         Holmes        Cink     Werenski
# 2018-06-17   Fleetwood        Johnson        Reed        Finau
# 2018-06-24        Cink        Hossler      Holmes        Casey
# 2018-07-01      Armour           Kang       Woods        Ancer
# 2018-07-08       Kraft       Snedeker      Kokrak      Niemann

# %%
#Current PGA Rankings

page = requests.get('http://www.owgr.com/ranking')
tree = html.fromstring(page.content)

#This will create a list of golfers:
golfers = tree.xpath('//table//td/a/text()')

b = 1
golfer_list = []

for a in golfers:
    
    c = a.split()
    row_dict = {"First Name" : c[0], "Last Name" : c[1],  "Ranking" : b}        
    golfer_list.append(row_dict)
    b = b + 1
    
df2 = pd.DataFrame(golfer_list)
df2 = df2.set_index("Ranking")

df2
# Out:
#          First Name    Last Name
# Ranking
# 1            Dustin      Johnson
# 2            Justin       Thomas
# 3            Justin         Rose
# 4            Brooks       Koepka
# 5               Jon         Rahm
# 6            Jordan       Spieth
# 7            Rickie       Fowler
# 8              Rory      McIlroy
# 9             Jason          Day
# 10            Tommy    Fleetwood
# 11          Patrick         Reed
# 12            Bubba       Watson
# 13             Paul        Casey
# 14             Alex        Noren
# 15           Hideki    Matsuyama
# 16        Francesco     Molinari
# 17           Henrik      Stenson
# 18             Marc     Leishman
# 19           Sergio       Garcia
# 20             Phil    Mickelson
# 21             Webb      Simpson
# 22           Bryson   DeChambeau
# 23          Tyrrell       Hatton
# 24           Xander   Schauffele
# 25           Rafael      Cabrera
# 26            Brian       Harman
# 27             Matt       Kuchar
# 28              Ian      Poulter
# 29          Patrick      Cantlay
# 30         Kiradech  Aphibarnrat
# ...             ...          ...
# 71             Ryan        Moore
# 72             Paul        Dunne
# 73           Yusaku     Miyazato
# 74            Aaron         Wise
# 75        Jhonattan        Vegas
# 76        Alexander        Bjork
# 77           Keegan      Bradley
# 78           Thomas      Pieters
# 79             Adam        Scott
# 80            Bernd   Wiesberger
# 81             J.B.       Holmes
# 82           Adrian      Otaegui
# 83       Shubhankar       Sharma
# 84             Yuta        Ikeda
# 85            James         Hahn
# 86            Joost       Luiten
# 87          Russell         Knox
# 88            Jorge     Campillo
# 89              Ted       Potter
# 90            Shane        Lowry
# 91            Chris         Wood
# 92            Billy     Horschel
# 93             Bill         Haas
# 94            Jamie     Lovemark
# 95           Brandt     Snedeker
# 96          Seungsu          Han
# 97          Stewart         Cink
# 98            Mikko     Korhonen
# 99          Anirban       Lahiri
# 100           Ryuko    Tokimatsu
#
# [100 rows x 2 columns]

# %%
top5_list=[]
top5 = 0
ranking = "+100"
player=np.unique(df[["Champion", "2nd", "3rd", "4th", "5th"]].values)
for i in player:
    top5=0
    for a in range(len(df.index)):
        if df.iloc[a]["Champion"] == i or df.iloc[a]["2nd"] == i or df.iloc[a]["3rd"] == i or df.iloc[a]["4th"] == i or df.iloc[a]["5th"] == i:
            top5 = top5 + 1
            date = df.index[a]
    try:
        a = df2.loc[df2['Last Name'] == i]
        ranking = a.index[0]
    except:
        ranking
       
    row_dict = {"Player" : i, "Top 5 Finishes" : top5, "Current Ranking" : ranking, "Most Recent Finish" : date}        
    top5_list.append(row_dict)
df1 = pd.DataFrame(top5_list)
df1 = df1.set_index("Player")
df1 = df1.sort_values(['Top 5 Finishes'], ascending=False)
df1 = df1[["Top 5 Finishes", "Current Ranking", "Most Recent Finish"]]

df1
# Out:
#              Top 5 Finishes Current Ranking Most Recent Finish
# Player
# Johnson                   5               1         2018-06-17
# Day                       4               9         2018-05-13
# DeChambeau                4              22         2018-06-03
# Woods                     3              67         2018-07-01
# Mickelson                 3              20         2018-05-06
# Na                        3              65         2018-07-08
# Rahm                      3               5         2018-04-08
# Holmes                    3              81         2018-06-24
# Reed                      3              11         2018-06-17
# Simpson                   3              21         2018-05-13
# Schwartzel                2              45         2018-05-13
# Rose                      2               3         2018-05-27
# Spieth                    2               6         2018-04-08
# Reavie                    2              54         2018-02-11
# Thomas                    2               2         2018-03-04
# Perez                     2              36         2018-04-29
# Noren                     2              14         2018-02-25
# Walker                    2              62         2018-05-13
# Watson                    2              12         2018-06-24
# List                      2              57         2018-04-15
# Landry                    2              70         2018-04-22
# Koepka                    2               4         2018-06-17
# Wise                      2              74         2018-05-20
# Hossler                   2              64         2018-06-24
# An                        2            +100         2018-06-03
# Fleetwood                 2              10         2018-06-17
# Finau                     2              31         2018-06-17
# Cink                      2              97         2018-06-24
# Casey                     2              13         2018-06-24
# Grillo                    2              50         2018-05-27
# ...                     ...             ...                ...
# Putnam                    1              28         2018-06-10
# Hoge                      1              23         2018-01-14
# Matsuyama                 1              15         2018-01-07
# Huh                       1              64         2018-01-21
# Hatton                    1              23         2018-03-04
# Kang                      1               1         2018-07-01
# Kim                       1              47         2018-04-15
# Kizzire                   1              69         2018-01-14
# Kodaira                   1              37         2018-04-15
# Harman                    1              26         2018-01-07
# Kokrak                    1               4         2018-07-08
# Kraft                     1               4         2018-07-08
# Hahn                      1              85         2018-01-14
# Leishman                  1              18         2018-05-20
# Hadwin                    1              48         2018-01-21
# McIlroy                   1               8         2018-03-18
# Poulter                   1              28         2018-04-01
# Hadley                    1              59         2018-02-04
# Ancer                     1            +100         2018-07-01
# Molinari                  1              16         2018-07-01
# Mullinax                  1              16         2018-04-22
# Niemann                   1              65         2018-07-08
# Grace                     1              34         2018-05-20
# O'Hair                    1              14         2018-04-22
# Palmer                    1              14         2018-01-28
# Garcia                    1              19         2018-03-11
# Piercy                    1              36         2018-04-29
# Piller                    1              36         2018-01-21
# Potter, Jr.               1              36         2018-02-11
# Mitchell                  1              20         2018-05-20
#
# [85 rows x 3 columns]

# %%
a = "Reed"

df1.loc[df1.index == a]
# Out:
#         Top 5 Finishes Current Ranking Most Recent Finish
# Player
# Reed                 3              11         2018-06-17

# %%
#Find all tournament IDs

#Check PGA for current tournament

PGA_current= "https://statdata.pgatour.com/r/current/message.json"
r = requests.get(PGA_current)
r_json = r.json()
current_id = r_json['tid']

tourn_id = []

champion_list = []

for i in range(0,500):
    
    if i < 10:
        i = "00{0}".format(i)
    elif i < 100:
        i = "0{0}".format(i)
    else:
        i = "{0}".format(i)
    
    try:
        
        current_url = "https://statdata.pgatour.com/r/{0}".format(i)

        #Current tournament's JSON

        PGA_current_url = "{0}/leaderboard-v2mini.json".format(current_url)

        r = requests.get(PGA_current_url)
        r_json = r.json()
        current_tournament = r_json["debug"]["tournament_in_schedule_file_name"]
        print(current_tournament)
        print(PGA_current_url)
        
        tourn_id.append(i)
        
    except:
        
        print(PGA_current_url, " DOES NOT WORK")

tourn_id
# Out:
# https://statdata.pgatour.com/r/000/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/001/leaderboard-v2mini.json  DOES NOT WORK
# CareerBuilder Challenge
# https://statdata.pgatour.com/r/002/leaderboard-v2mini.json
# Waste Management Phoenix Open
# https://statdata.pgatour.com/r/003/leaderboard-v2mini.json
# Farmers Insurance Open
# https://statdata.pgatour.com/r/004/leaderboard-v2mini.json
# AT&T Pebble Beach Pro-Am
# https://statdata.pgatour.com/r/005/leaderboard-v2mini.json
# Sony Open in Hawaii
# https://statdata.pgatour.com/r/006/leaderboard-v2mini.json
# Genesis Open
# https://statdata.pgatour.com/r/007/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/008/leaderboard-v2mini.json  DOES NOT WORK
# Arnold Palmer Invitational presented by Mastercard
# https://statdata.pgatour.com/r/009/leaderboard-v2mini.json
# The Honda Classic
# https://statdata.pgatour.com/r/010/leaderboard-v2mini.json
# THE PLAYERS Championship
# https://statdata.pgatour.com/r/011/leaderboard-v2mini.json
# RBC Heritage
# https://statdata.pgatour.com/r/012/leaderboard-v2mini.json
# Wyndham Championship
# https://statdata.pgatour.com/r/013/leaderboard-v2mini.json
# Masters Tournament
# https://statdata.pgatour.com/r/014/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/015/leaderboard-v2mini.json  DOES NOT WORK
# Sentry Tournament of Champions
# https://statdata.pgatour.com/r/016/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/017/leaderboard-v2mini.json  DOES NOT WORK
# Zurich Classic of New Orleans
# https://statdata.pgatour.com/r/018/leaderboard-v2mini.json
# AT&T Byron Nelson
# https://statdata.pgatour.com/r/019/leaderboard-v2mini.json
# Houston Open
# https://statdata.pgatour.com/r/020/leaderboard-v2mini.json
# Fort Worth Invitational
# https://statdata.pgatour.com/r/021/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/022/leaderboard-v2mini.json  DOES NOT WORK
# the Memorial Tournament presented by Nationwide
# https://statdata.pgatour.com/r/023/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/024/leaderboard-v2mini.json  DOES NOT WORK
# FedEx St. Jude Classic
# https://statdata.pgatour.com/r/025/leaderboard-v2mini.json
# U.S. Open
# https://statdata.pgatour.com/r/026/leaderboard-v2mini.json
# THE NORTHERN TRUST
# https://statdata.pgatour.com/r/027/leaderboard-v2mini.json
# BMW Championship
# https://statdata.pgatour.com/r/028/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/029/leaderboard-v2mini.json  DOES NOT WORK
# John Deere Classic
# https://statdata.pgatour.com/r/030/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/031/leaderboard-v2mini.json  DOES NOT WORK
# RBC Canadian Open
# https://statdata.pgatour.com/r/032/leaderboard-v2mini.json
# PGA Championship
# https://statdata.pgatour.com/r/033/leaderboard-v2mini.json
# Travelers Championship
# https://statdata.pgatour.com/r/034/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/035/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/036/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/037/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/038/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/039/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/040/leaderboard-v2mini.json  DOES NOT WORK
# Valero Texas Open
# https://statdata.pgatour.com/r/041/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/042/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/043/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/044/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/045/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/046/leaderboard-v2mini.json  DOES NOT WORK
# Shriners Hospitals for Children Open
# https://statdata.pgatour.com/r/047/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/048/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/049/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/050/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/051/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/052/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/053/leaderboard-v2mini.json  DOES NOT WORK
# Sanderson Farms Championship
# https://statdata.pgatour.com/r/054/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/055/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/056/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/057/leaderboard-v2mini.json  DOES NOT WORK
# QBE Shootout
# https://statdata.pgatour.com/r/058/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/059/leaderboard-v2mini.json  DOES NOT WORK
# TOUR Championship
# https://statdata.pgatour.com/r/060/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/061/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/062/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/063/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/064/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/065/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/066/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/067/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/068/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/069/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/070/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/071/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/072/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/073/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/074/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/075/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/076/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/077/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/078/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/079/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/080/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/081/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/082/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/083/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/084/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/085/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/086/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/087/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/088/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/089/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/090/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/091/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/092/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/093/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/094/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/095/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/096/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/097/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/098/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/099/leaderboard-v2mini.json  DOES NOT WORK
# The Open Championship
# https://statdata.pgatour.com/r/100/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/101/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/102/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/103/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/104/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/105/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/106/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/107/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/108/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/109/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/110/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/111/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/112/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/113/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/114/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/115/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/116/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/117/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/118/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/119/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/120/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/121/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/122/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/123/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/124/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/125/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/126/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/127/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/128/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/129/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/130/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/131/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/132/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/133/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/134/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/135/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/136/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/137/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/138/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/139/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/140/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/141/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/142/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/143/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/144/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/145/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/146/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/147/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/148/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/149/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/150/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/151/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/152/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/153/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/154/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/155/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/156/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/157/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/158/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/159/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/160/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/161/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/162/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/163/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/164/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/165/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/166/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/167/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/168/leaderboard-v2mini.json  DOES NOT WORK
# ISPS HANDA World Cup of Golf
# https://statdata.pgatour.com/r/169/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/170/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/171/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/172/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/173/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/174/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/175/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/176/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/177/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/178/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/179/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/180/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/181/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/182/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/183/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/184/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/185/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/186/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/187/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/188/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/189/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/190/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/191/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/192/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/193/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/194/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/195/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/196/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/197/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/198/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/199/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/200/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/201/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/202/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/203/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/204/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/205/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/206/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/207/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/208/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/209/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/210/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/211/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/212/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/213/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/214/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/215/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/216/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/217/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/218/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/219/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/220/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/221/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/222/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/223/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/224/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/225/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/226/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/227/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/228/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/229/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/230/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/231/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/232/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/233/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/234/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/235/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/236/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/237/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/238/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/239/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/240/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/241/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/242/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/243/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/244/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/245/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/246/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/247/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/248/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/249/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/250/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/251/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/252/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/253/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/254/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/255/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/256/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/257/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/258/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/259/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/260/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/261/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/262/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/263/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/264/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/265/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/266/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/267/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/268/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/269/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/270/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/271/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/272/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/273/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/274/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/275/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/276/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/277/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/278/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/279/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/280/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/281/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/282/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/283/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/284/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/285/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/286/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/287/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/288/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/289/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/290/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/291/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/292/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/293/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/294/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/295/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/296/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/297/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/298/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/299/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/300/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/301/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/302/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/303/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/304/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/305/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/306/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/307/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/308/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/309/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/310/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/311/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/312/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/313/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/314/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/315/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/316/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/317/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/318/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/319/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/320/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/321/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/322/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/323/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/324/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/325/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/326/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/327/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/328/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/329/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/330/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/331/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/332/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/333/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/334/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/335/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/336/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/337/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/338/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/339/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/340/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/341/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/342/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/343/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/344/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/345/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/346/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/347/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/348/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/349/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/350/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/351/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/352/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/353/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/354/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/355/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/356/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/357/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/358/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/359/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/360/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/361/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/362/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/363/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/364/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/365/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/366/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/367/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/368/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/369/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/370/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/371/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/372/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/373/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/374/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/375/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/376/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/377/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/378/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/379/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/380/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/381/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/382/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/383/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/384/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/385/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/386/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/387/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/388/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/389/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/390/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/391/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/392/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/393/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/394/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/395/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/396/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/397/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/398/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/399/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/400/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/401/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/402/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/403/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/404/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/405/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/406/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/407/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/408/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/409/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/410/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/411/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/412/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/413/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/414/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/415/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/416/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/417/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/418/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/419/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/420/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/421/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/422/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/423/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/424/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/425/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/426/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/427/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/428/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/429/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/430/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/431/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/432/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/433/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/434/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/435/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/436/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/437/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/438/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/439/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/440/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/441/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/442/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/443/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/444/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/445/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/446/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/447/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/448/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/449/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/450/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/451/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/452/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/453/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/454/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/455/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/456/leaderboard-v2mini.json  DOES NOT WORK
# OHL Classic at Mayakoba
# https://statdata.pgatour.com/r/457/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/458/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/459/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/460/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/461/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/462/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/463/leaderboard-v2mini.json  DOES NOT WORK
# Safeway Open
# https://statdata.pgatour.com/r/464/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/465/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/466/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/467/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/468/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/469/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/470/leaderboard-v2mini.json  DOES NOT WORK
# Quicken Loans National
# https://statdata.pgatour.com/r/471/leaderboard-v2mini.json
# Barracuda Championship
# https://statdata.pgatour.com/r/472/leaderboard-v2mini.json
# World Golf Championships-Mexico Championship
# https://statdata.pgatour.com/r/473/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/474/leaderboard-v2mini.json  DOES NOT WORK
# Valspar Championship
# https://statdata.pgatour.com/r/475/leaderboard-v2mini.json
# World Golf Championships-Bridgestone Invitational
# https://statdata.pgatour.com/r/476/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/477/leaderboard-v2mini.json  DOES NOT WORK
# Hero World Challenge
# https://statdata.pgatour.com/r/478/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/479/leaderboard-v2mini.json  DOES NOT WORK
# Wells Fargo Championship
# https://statdata.pgatour.com/r/480/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/481/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/482/leaderboard-v2mini.json  DOES NOT WORK
# Puerto Rico Open
# https://statdata.pgatour.com/r/483/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/484/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/485/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/486/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/487/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/488/leaderboard-v2mini.json  DOES NOT WORK
# World Golf Championships-HSBC Champions
# https://statdata.pgatour.com/r/489/leaderboard-v2mini.json
# A Military Tribute at The Greenbrier
# https://statdata.pgatour.com/r/490/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/491/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/492/leaderboard-v2mini.json  DOES NOT WORK
# The RSM Classic
# https://statdata.pgatour.com/r/493/leaderboard-v2mini.json
# CIMB Classic
# https://statdata.pgatour.com/r/494/leaderboard-v2mini.json
# https://statdata.pgatour.com/r/495/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/496/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/497/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/498/leaderboard-v2mini.json  DOES NOT WORK
# https://statdata.pgatour.com/r/499/leaderboard-v2mini.json  DOES NOT WORK
# ['002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '009',
#  '010',
#  '011',
#  '012',
#  '013',
#  '014',
#  '016',
#  '018',
#  '019',
#  '020',
#  '021',
#  '023',
#  '025',
#  '026',
#  '027',
#  '028',
#  '030',
#  '032',
#  '033',
#  '034',
#  '041',
#  '047',
#  '054',
#  '058',
#  '060',
#  '100',
#  '169',
#  '457',
#  '464',
#  '471',
#  '472',
#  '473',
#  '475',
#  '476',
#  '478',
#  '480',
#  '483',
#  '489',
#  '490',
#  '493',
#  '494']
